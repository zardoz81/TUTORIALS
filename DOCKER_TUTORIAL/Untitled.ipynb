# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = open('dump.txt', 'a')
f.writelines(['asdfasd/n'])
f.close()

# %%
# %matplotlib notebook
plt.plot([1,2],[1,2])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import os

os.environ['DISPLAY']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-7b05d3a6f234> in <module>
#       1 import os
#       2
# ----> 3 os.environ['DISPLAY']
#
# /usr/local/lib/python3.7/os.py in __getitem__(self, key)
#     676         except KeyError:
#     677             # raise KeyError with the original key value
# --> 678             raise KeyError(key) from None
#     679         return self.decodevalue(value)
#     680
#
# KeyError: 'DISPLAY'

# %%
import pyautogui
pyautogui.position()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/Xlib/support/unix_connect.py in get_socket(dname, host, dno)
#      75             s = socket.socket(socket.AF_UNIX, socket.SOCK_STREAM)
# ---> 76             s.connect('/tmp/.X11-unix/X%d' % dno)
#      77     except OSError as val:
#
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DisplayConnectionError                    Traceback (most recent call last)
# <ipython-input-16-ebc2cd573d17> in <module>
# ----> 1 import pyautogui
#       2 pyautogui.position()
#
# /usr/local/lib/python3.7/site-packages/pyautogui/__init__.py in <module>
#      92
#      93 try:
# ---> 94     import mouseinfo
#      95     def mouseInfo():
#      96         mouseinfo.MouseInfoWindow()
#
# ...
