# %%
import requests
apikey = '3fee8092-d268-42df-bba0-bacc4b15ca7f'
string = 'МГУ ломо'
req = f'https://geocode-maps.yandex.ru/1.x/?format=json&apikey={apikey}&geocode={string}'
r = requests.get(req)
print(r.status_code)
# Out:
# 200

# %%
r.json()
# Out:
# {'response': {'GeoObjectCollection': {'metaDataProperty': {'GeocoderResponseMetaData': {'request': 'МГУ ломо',
#      'results': '10',
#      'found': '35'}},
#    'featureMember': [{'GeoObject': {'metaDataProperty': {'GeocoderMetaData': {'precision': 'other',
#         'text': "Кот-д'Ивуар, Ломо",
#         'kind': 'locality',
#         'Address': {'country_code': 'CI',
#          'formatted': "Кот-д'Ивуар, Ломо",
#          'Components': [{'kind': 'country', 'name': "Кот-д'Ивуар"},
#           {'kind': 'locality', 'name': 'Ломо'}]},
#         'AddressDetails': {'Country': {'AddressLine': "Кот-д'Ивуар, Ломо",
#           'CountryNameCode': 'CI',
#           'CountryName': "Кот-д'Ивуар",
#           'Locality': {'LocalityName': 'Ломо'}}}}},
#       'name': 'Ломо',
#       'description': "Кот-д'Ивуар",
#       'boundedBy': {'Envelope': {'lowerCorner': '-3.081572 7.812313',
#         'upperCorner': '-2.949771 7.943734'}},
#       'Point': {'pos': '-3.015671 7.878029'}}},
# ...

# %%
r.json()['response']['GeoObjectCollection']['metaDataProperty'].keys()
# Out:
# dict_keys(['GeocoderResponseMetaData'])
